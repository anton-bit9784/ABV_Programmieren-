# %%
print("Hello World Leck Eier")
x = 10
print(x * 100 + 67)
# Out:
# Hello World Leck Eier
# 1067

# %%
zahlen = int(101)
liste = [1,2,3]

print(zahlen)
print(type(zahlen))
print(liste[0])
print(type(liste))
# Out:
# 101
# <class 'int'>
# 1
# <class 'list'>

# %%
text = """Hallo
1
2
3
"""
print(text)
# Out:
# Hallo
# 1
# 2
# 3

# %%
text1 = f"Hallo, du bist Nummer {zahl1}" 

print(text1)
# Out:
# Hallo, du bist Nummer 2

# %%
s = "PYTHON"
print(s[0], s[-1], s[1:4], s[ :3], s[::2])
# Out:
# P N YTH PYT PTO

# %%
zahl1 = -2
zahl2 = 7

# %%
zahl1 += 3
print(zahl1)
# Out:
# 10

# %%
alex = str(input("Ist Alex Dumm?: "))
print(f"Genau Richtig {alex}")
# Out:
# Ist Alex Dumm?:  Ja
# Genau Richtig Ja

# %%
if zahl1 == 1:
    print("Alex ist dumm")
elif zahl1 == 2 or zahl2 > 3:
    print("Alexander Jahn Bauer")
else:
    print("Alex ist ein Bastard")
# Out:
# Alexander Jahn Bauer
